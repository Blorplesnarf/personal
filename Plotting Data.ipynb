# %% [markdown]
# ## Import dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook
import seaborn; seaborn.set()

# %% [markdown]
# Now to import the data from file and use as a padas dataframe

# %%
#Name of the file to be loaded
filename = 'Monitoring_20170721_110038.txt'

#Use the pandas csv reader function
#There is no header, whitespace delimited, first column is an index
data = pd.read_csv(filename, delim_whitespace=True, header=None, index_col=0, names=['time', 'current1', 'current2'])

# %% [markdown]
# Check what the data looks like by looking at the first few rows

# %%
data.head()
# Out:
#            time  current1  current2
# 1  11:00:57.559         0         0
# 2  11:00:57.563         0         0
# 3  11:00:57.565         0         0
# 4  11:00:57.567         0         0
# 5  11:00:57.569         0         0

# %% [markdown]
# Check what type of data types the columns are

# %%
data.dtypes
# Out:
# time        object
# current1     int64
# current2     int64
# dtype: object

# %%
#It can be seen that time is 'obbject' which will be a standard string
#Parse the time column and convert to a Date Time object
data['DateTime']=pd.to_datetime(data['time'])

# %%
data.head()
# Out:
#            time  current1  current2                DateTime
# 1  11:00:57.559         0         0 2017-07-27 11:00:57.559
# 2  11:00:57.563         0         0 2017-07-27 11:00:57.563
# 3  11:00:57.565         0         0 2017-07-27 11:00:57.565
# 4  11:00:57.567         0         0 2017-07-27 11:00:57.567
# 5  11:00:57.569         0         0 2017-07-27 11:00:57.569

# %%
data.dtypes
# Out:
# time                object
# current1             int64
# current2             int64
# DateTime    datetime64[ns]
# dtype: object

# %% [markdown]
# Now that the time column is no longer needed drop it

# %%
data.drop(['time'], axis=1)
# Out:
#         current1  current2                DateTime
# 1              0         0 2017-07-27 11:00:57.559
# 2              0         0 2017-07-27 11:00:57.563
# 3              0         0 2017-07-27 11:00:57.565
# 4              0         0 2017-07-27 11:00:57.567
# 5              0         0 2017-07-27 11:00:57.569
# 6              0         0 2017-07-27 11:00:57.571
# 7              0         0 2017-07-27 11:00:57.573
# 8              0         0 2017-07-27 11:00:57.575
# 9              0         0 2017-07-27 11:00:57.577
# 10             0         0 2017-07-27 11:00:57.583
# 11             1         0 2017-07-27 11:00:57.585
# 12             2         0 2017-07-27 11:00:57.587
# 13             3         0 2017-07-27 11:00:57.589
# 14             0         0 2017-07-27 11:00:57.590
# 15             0         1 2017-07-27 11:00:57.592
# 16             0         0 2017-07-27 11:00:57.594
# 17             0         0 2017-07-27 11:00:57.596
# 18             0         0 2017-07-27 11:00:57.598
# 19             0         0 2017-07-27 11:00:57.600
# 20             0         7 2017-07-27 11:00:57.604
# 21             0         4 2017-07-27 11:00:57.605
# 22             7         1 2017-07-27 11:00:57.607
# 23             0         0 2017-07-27 11:00:57.609
# 24             8         1 2017-07-27 11:00:57.610
# 25             1         0 2017-07-27 11:00:57.612
# 26             4         0 2017-07-27 11:00:57.614
# 27             8         0 2017-07-27 11:00:57.615
# 28             8         3 2017-07-27 11:00:57.617
# 29             4         0 2017-07-27 11:00:57.619
# 30             1         0 2017-07-27 11:00:57.623
# ...          ...       ...                     ...
# 282203       480       627 2017-07-27 18:48:15.499
# 282204       484       633 2017-07-27 18:48:15.502
# 282205       480       622 2017-07-27 18:48:15.504
# 282206       487       640 2017-07-27 18:48:15.955
# 282207       440       655 2017-07-27 18:48:15.956
# 282208       506       632 2017-07-27 18:48:16.466
# 282209       478       621 2017-07-27 18:48:16.467
# 282210       505       611 2017-07-27 18:48:16.471
# 282211       476       630 2017-07-27 18:48:16.481
# 282212       440       647 2017-07-27 18:48:16.482
# 282213       484       662 2017-07-27 18:48:16.483
# 282214       456       613 2017-07-27 18:48:16.485
# 282215       488       651 2017-07-27 18:48:16.486
# 282216       484       643 2017-07-27 18:48:16.488
# 282217       485       680 2017-07-27 18:48:16.489
# 282218       449       671 2017-07-27 18:48:16.490
# 282219       447       647 2017-07-27 18:48:16.492
# 282220       440       613 2017-07-27 18:48:16.551
# 282221       453       678 2017-07-27 18:48:16.650
# 282222       447       670 2017-07-27 18:48:16.801
# 282223       472       630 2017-07-27 18:48:16.849
# 282224       490       670 2017-07-27 18:48:16.952
# 282225       503       636 2017-07-27 18:48:17.077
# 282226       472       624 2017-07-27 18:48:17.154
# 282227       513       655 2017-07-27 18:48:17.238
# 282228       459       687 2017-07-27 18:48:17.377
# 282229       449       671 2017-07-27 18:48:17.449
# 282230       513       641 2017-07-27 18:48:17.551
# 282231       486       651 2017-07-27 18:48:17.654
# 282232       448       663 2017-07-27 18:48:17.749
#
# [282232 rows x 3 columns]

# %%
#Move the DateTime column to the first column
data=data[['DateTime', 'current1', 'current2']]

# %%
data.head()
# Out:
#                  DateTime  current1  current2
# 1 2017-07-27 11:00:57.559         0         0
# 2 2017-07-27 11:00:57.563         0         0
# 3 2017-07-27 11:00:57.565         0         0
# 4 2017-07-27 11:00:57.567         0         0
# 5 2017-07-27 11:00:57.569         0         0

# %%
data.dtypes
# Out:
# DateTime    datetime64[ns]
# current1             int64
# current2             int64
# dtype: object

# %%
data['DateTime']=data['DateTime'] - data['DateTime'].iloc[0]

# %%
data.head()
# Out:
#          DateTime  current1  current2
# 1        00:00:00         0         0
# 2 00:00:00.004000         0         0
# 3 00:00:00.006000         0         0
# 4 00:00:00.008000         0         0
# 5 00:00:00.010000         0         0

# %%
data.dtypes
# Out:
# DateTime    timedelta64[ns]
# current1              int64
# current2              int64
# dtype: object

# %%
data['seconds']=data['DateTime'].dt.total_seconds()
data.head()
# Out:
#          DateTime  current1  current2  seconds
# 1        00:00:00         0         0    0.000
# 2 00:00:00.004000         0         0    0.004
# 3 00:00:00.006000         0         0    0.006
# 4 00:00:00.008000         0         0    0.008
# 5 00:00:00.010000         0         0    0.010

# %%
#Plot the data using the seconds as the x axis index

fig, ax = plt.subplots(2, sharex=True)

data[['seconds', 'current1']].plot(ax=ax[0], color='red', x='seconds')
data[['seconds', 'current2']].plot(ax=ax[1], x='seconds')
# Out:
# <img src="data:image/png;base64,...">

# %%
data['smooth1']=data['current1'].rolling(100, center=True).mean()
data['smooth2']=data['current2'].rolling(100, center=True).mean()
data.head()
# Out:
#          DateTime  current1  current2  seconds  smooth1  smooth2
# 1        00:00:00         0         0    0.000      NaN      NaN
# 2 00:00:00.004000         0         0    0.004      NaN      NaN
# 3 00:00:00.006000         0         0    0.006      NaN      NaN
# 4 00:00:00.008000         0         0    0.008      NaN      NaN
# 5 00:00:00.010000         0         0    0.010      NaN      NaN

# %%
data['std1']=data['current1'].rolling(100, center=True).std()
data['std2']=data['current2'].rolling(100, center=True).std()

# %%
#Plot the data using the seconds as the x axis index

fig, ax = plt.subplots(4, sharex=True)

data[['seconds', 'current1']].plot(ax=ax[0], color='red', x='seconds', alpha=0.3)
data[['seconds', 'smooth1']].plot(ax=ax[0], color='red', x='seconds', linestyle=':')
data[['seconds', 'std1']].plot(ax=ax[1], color='red', x='seconds')
data[['seconds', 'current2']].plot(ax=ax[2], x='seconds', alpha=0.3)
data[['seconds', 'smooth2']].plot(ax=ax[2], x='seconds', linestyle=':')
data[['seconds', 'std2']].plot(ax=ax[3], color='red', x='seconds')
# Out:
# <img src="data:image/png;base64,...">
